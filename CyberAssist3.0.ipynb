# %% [markdown]
# <a href="https://colab.research.google.com/github/Zardian18/CyberAssist/blob/master/CyberAssist3.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers
# !pip install -U accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 39.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.38.2
#     Uninstalling transformers-4.38.2:
#       Successfully uninstalled transformers-4.38.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 59.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 71.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 100.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.9 MB/s eta 0:00:00
# ...

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.6 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

dataset = load_dataset("ahmed000000000/cybersec")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset2 = load_dataset("dzakwan/cybersec")
# Out:
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['INSTRUCTION', 'RESPONSE'],
#         num_rows: 12408
#     })
# })

# %%
dataset2
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['output', 'instruction', 'input'],
#         num_rows: 13982
#     })
# })

# %%
import pandas as pd

# %%
train_ds = pd.DataFrame(dataset["train"])
train_ds
# Out:
#                                              INSTRUCTION  \
# 0      Can you explain how to use WNetAddConnection t...
# 1      Compare and contrast the security features of ...
# 2      Define 'Clickjacking' and describe how it can ...
# 3      Define 'Computed IOCs' and give examples of ea...
# 4      Define 'Containment and intelligence developme...
# ...                                                  ...
# 12403  What design issue can be exploited to imperson...
# 12404  Explain how responder-like activity can be det...
# 12405  What is osquery and how can it be used to dete...
# 12406  Explain how to detect the Netsh persistence te...
# 12407  What is the Windows event ID that is logged wh...
#
#                                                 RESPONSE
# 0      To use WNetAddConnection to map a network shar...
# 1      All three web servers have different security ...
# 2      Clickjacking is a type of attack where a malic...
# ...

# %%
train2_ds = pd.DataFrame(dataset2["train"])
train2_ds
# Out:
#                                                   output  \
# 0      After conducting the risk assessment, I've ide...
# 1      Based on the analysis of the attack, I've iden...
# 2      After evaluating the DLP solution, I found tha...
# 3      After investigating, I've determined that the ...
# 4      After conducting the penetration test, I've id...
# ...                                                  ...
# 13977  Based on the network logs, we have identified ...
# 13978  The first step is to isolate the infected serv...
# 13979  We recommend implementing strong password requ...
# 13980  We have identified several indicators of compr...
# 13981  We have identified several areas of non-compli...
#
#                                              instruction  \
# 0      Conduct a thorough risk assessment for a new e...
# 1      Perform a TTP mapping for a recent cyber attac...
# 2      Evaluate the effectiveness of a newly implemen...
# ...

# %%
train_final_df = pd.DataFrame()
train_final_df['Input'] = pd.concat([train_ds['INSTRUCTION'], train2_ds['input']], ignore_index=True)
train_final_df['Output'] = pd.concat([train_ds['RESPONSE'], train2_ds['output']], ignore_index=True)

train_final_df.head()
# Out:
#                                                Input  \
# 0  Can you explain how to use WNetAddConnection t...
# 1  Compare and contrast the security features of ...
# 2  Define 'Clickjacking' and describe how it can ...
# 3  Define 'Computed IOCs' and give examples of ea...
# 4  Define 'Containment and intelligence developme...
#
#                                               Output
# 0  To use WNetAddConnection to map a network shar...
# 1  All three web servers have different security ...
# 2  Clickjacking is a type of attack where a malic...
# 3  Computed IOCs refer to Indicators of Compromis...
# 4  Containment and intelligence development is a ...

# %%
train_final_df
# Out:
#                                                    Input  \
# 0      Can you explain how to use WNetAddConnection t...
# 1      Compare and contrast the security features of ...
# 2      Define 'Clickjacking' and describe how it can ...
# 3      Define 'Computed IOCs' and give examples of ea...
# 4      Define 'Containment and intelligence developme...
# ...                                                  ...
# 26385  Review the network logs from the past 24 hours...
# 26386  We have detected a ransomware attack on our co...
# 26387  Please review the user access policies for our...
# 26388  Please conduct a threat hunt to identify any p...
# 26389  Please verify that our organization is in comp...
#
#                                                   Output
# 0      To use WNetAddConnection to map a network shar...
# 1      All three web servers have different security ...
# 2      Clickjacking is a type of attack where a malic...
# ...

# %%
text_data = train_final_df["Output"]
text_data
# Out:
# 0        To use WNetAddConnection to map a network shar...
# 1        All three web servers have different security ...
# 2        Clickjacking is a type of attack where a malic...
# 3        Computed IOCs refer to Indicators of Compromis...
# 4        Containment and intelligence development is a ...
#                                ...
# 26385    Based on the network logs, we have identified ...
# 26386    The first step is to isolate the infected serv...
# 26387    We recommend implementing strong password requ...
# 26388    We have identified several indicators of compr...
# 26389    We have identified several areas of non-compli...
# Name: Output, Length: 26390, dtype: object

# %%
text_data.to_csv('text_final.txt', index=False, header=False)

# %%
# !mkdir output

# %% [markdown]
# ## Training

# %%
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, GPT2Config
from transformers import TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments
from transformers import AutoTokenizer, AutoModelForCausalLM


text_data_path = "/content/text_final.txt"

tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2-medium")
model = AutoModelForCausalLM.from_pretrained("openai-community/gpt2-medium")

with open(text_data_path, "r", encoding="utf-8") as file:
    text_data = file.read()

tokenized_data = tokenizer.encode(text_data, return_tensors="pt")

dataset = TextDataset(
    tokenizer=tokenizer,
    file_path=text_data_path,
    block_size=128,
)
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)


training_args = TrainingArguments(
    output_dir="/content/output",
    overwrite_output_dir=True,
    num_train_epochs=20,
    per_device_train_batch_size=8,
    save_steps=2000,
    save_total_limit=3,
)


trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dataset,
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/718 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (2594783 > 1024). Running this sequence through the model will result in indexing errors
# ...

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 1024)
#     (wpe): Embedding(1024, 1024)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPT2Block(
#         (ln_1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=1024, out_features=50257, bias=False)
# )

# %%
trainer.train()

# %%
model.push_to_hub("Cyber_assist3.0")
tokenizer.push_to_hub("Cyber_assist3.0")
# Out:
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.18k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Zardian/Cyber_assist3.0/commit/72d3871df64229385cb21df90af03e9a12f1f041', commit_message='Upload tokenizer', commit_description='', oid='72d3871df64229385cb21df90af03e9a12f1f041', pr_url=None, pr_revision=None, pr_num=None)

# %%
# from transformers import pipeline
# model_id = "Zardian/output"
# generator = pipeline("text-generation", model=model_id)

# %%
import torch.nn.functional as F

def log_probs_from_logits(logits, labels):
    logp = F.log_softmax(logits, dim=-1)
    logp_label = torch.gather(logp, 2, labels.unsqueeze(2)).squeeze(-1)
    return logp_label

def sequence_logprob(model, labels, input_len=0):
    with torch.no_grad():
        output = model(labels)
        log_probs = log_probs_from_logits(
            output.logits[:, :-1, :], labels[:, 1:])
        seq_log_prob = torch.sum(log_probs[:, input_len:])
    return seq_log_prob.cpu().numpy()

# %%
input_txt ="What is ransomware?"

# %%
import torch

# Check if GPU is available and choose the appropriate device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# input_txt = "Transformers are the"
input_ids = tokenizer(input_txt, return_tensors="pt")["input_ids"].to(device)
iterations = []
n_steps = 100
choices_per_step = 5

# %%
input_ids = tokenizer(input_txt, return_tensors="pt")["input_ids"].to(device)
output_greedy = model.generate(input_ids, max_length=150,
                               do_sample=False)
print(tokenizer.decode(output_greedy[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What is ransomware?
#
# Ransomware is a type of malicious software that encrypts files on a victim's computer and demands a ransom for the decryption key. It spreads rapidly through networks and systems, encrypting important files and demanding payment in exchange for the decryption key. The impact of ransomware on cybersecurity is significant, as it can lead to data loss, financial loss, and reputational damage. It is important for individuals and organizations to be cautious of unsolicited emails, phone calls, and other forms of social engineering, to prevent falling victim to ransomware attacks."
# ...

# %%
input_ids = tokenizer(input_txt, return_tensors="pt")["input_ids"].to(device)
output = model.generate(input_ids, max_new_tokens=n_steps, do_sample=False)
print(tokenizer.decode(output[0]))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What is ransomware?
#
# Ransomware is a type of malicious software that encrypts files or locks users out of their computer. It is often used by attackers to extort money from victims by demanding a ransom in exchange for their release of the files.
#
# The term 'Ransomware ransom' refers to the method used by attackers to extort money from victims. It involves demanding a ransom in exchange for the release of the files, often through encrypted channels. This technique is often used to extort money

# %%
logp = sequence_logprob(model, output_greedy, input_len=len(input_ids[0]))
print(tokenizer.decode(output_greedy[0]))
print(f"\nlog-prob: {logp:.2f}")
# Out:
# What is ransomware?
#
# Ransomware is a type of malicious software that encrypts files on a victim's computer and demands a ransom for the decryption key. It spreads rapidly through networks and systems, encrypting important files and demanding payment in exchange for the decryption key. The impact of ransomware on cybersecurity is significant, as it can lead to data loss, financial loss, and reputational damage. It is important for individuals and organizations to be cautious of unsolicited emails, phone calls, and other forms of social engineering, to prevent falling victim to ransomware attacks."
# "Ransomware is a type of malicious software that encrypts files on a victim's computer and demands a ransom for the decryption key. It spreads rapidly through
#
# log-prob: -62.90

# %%
output_beam = model.generate(input_ids, max_length=150, num_beams=5,
                             do_sample=False)
logp = sequence_logprob(model, output_beam, input_len=len(input_ids[0]))
print(tokenizer.decode(output_beam[0]))
print(f"\nlog-prob: {logp:.2f}")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# What is ransomware?
# Ransomware is a type of malicious software that encrypts files on a victim's computer and demands payment in exchange for the decryption key. It can be delivered through various means, such as email attachments or malicious websites. Once installed on the victim's computer, the ransomware encrypts files and demands payment in exchange for the decryption key. This type of ransomware poses a significant threat to cybersecurity as it can lead to data theft, unauthorized access, and disruption of services. It is important for individuals and organizations to be aware of this type of malware and implement robust cybersecurity measures to protect against it."
# ...

# %%
import locale
print(locale.getpreferredencoding())
# Out:
# ANSI_X3.4-1968

# %%
import locale
def getpreferredencoding(do_setlocale = True):
    return "UTF-8"
locale.getpreferredencoding = getpreferredencoding

# %%
# !pip install -q gradio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 53.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 28.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 59.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 9.6 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

# %%
model
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50257, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-11): 12 x GPT2Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): GPT2Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPT2MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (act): NewGELUActivation()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50257, bias=False)
# )

# %%
# def generate_text(inp):
#   input_ids = tokenizer.encode(inp, return_tensors="pt")
#   beam_output = model.generate(input_ids, max_len=150, num_beams=5, no_repeat_ngram_size=2, early_stopping=True)
#   output = tokenizer.decode(beam_output[0], skip_special_tokens=True, clean_up_tokenization_spaces=True)
#   return ".".join(output.split(".")[:-1])+ "."

# %%
def generate_text(inp):
  input_ids = tokenizer(inp, return_tensors="pt")["input_ids"].to(device)
  output = model.generate(input_ids, max_new_tokens=n_steps, do_sample=False)
  return tokenizer.decode(output[0])

# %%
generate_text("what is ransomware")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'what is ransomware, and what is the impact of the ransomware attack on the organization\'s cybersecurity posture."\n"The term \'Ransomware Empire\' refers to a type of ransomware that is highly sophisticated and targeted. It is known for its ability to encrypt files and spread rapidly across infected systems. Unlike traditional ransomware, which focuses on long-term storage and distribution, ransomware Empire uses a variety of techniques to deliver its malicious payloads. These techniques include exploiting vulnerabilities in software, installing backdoors, and using social engineering'

# %%
import gradio as gr
iface = gr.Interface(
    fn=generate_text,
    inputs="textbox",
    outputs="text",
    title="CYBERSEC_ASSISTANT",
    description="fine tuned gpt2"
)
iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://24cf3a0264b265cf20.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://24cf3a0264b265cf20.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
